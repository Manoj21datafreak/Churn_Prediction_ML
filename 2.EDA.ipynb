# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import numpy as np
df = pd.read_csv("/content/drive/MyDrive/Dataset/Telco-Customer-Churn.csv")
# Out:
# Mounted at /content/drive

# %%
pd.set_option("display.max_columns", 100)

# %%
df["TotalCharges"] = df["TotalCharges"].replace(" ", np.nan)
df["TotalCharges"] = df["TotalCharges"].astype(float)

# %%
churn_counts = df["Churn"].value_counts()
churn_pct = df["Churn"].value_counts(normalize=True) * 100

print(churn_counts)
print(churn_pct)
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
pd.crosstab(df["Contract"], df["Churn"], normalize="index") * 100
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.730482  11.269518
# Two year        97.168142   2.831858

# %%
df.groupby("Churn")["tenure"].describe()
# Out:
#         count       mean        std  min   25%   50%   75%   max
# Churn
# No     5174.0  37.569965  24.113777  0.0  15.0  38.0  61.0  72.0
# Yes    1869.0  17.979133  19.531123  1.0   2.0  10.0  29.0  72.0

# %%
import matplotlib.pyplot as plt
plt.hist(df[df["Churn"]=="Yes"]["tenure"], alpha=0.7, label="Churned")
plt.hist(df[df["Churn"]=="No"]["tenure"], alpha=0.7, label="Not Churned")
plt.legend()
plt.xlabel("Tenure")
plt.ylabel("Count")
plt.title("Tenure Distribution by Churn")
plt.show()

# %%
pd.crosstab(df["Dependents"], df["Churn"], normalize="index") * 100
# Out:
# Churn              No        Yes
# Dependents
# No          68.720860  31.279140
# Yes         84.549763  15.450237

# %%
pd.crosstab(df["Partner"], df["Churn"], normalize="index") * 100
# Out:
# Churn           No        Yes
# Partner
# No       67.042021  32.957979
# Yes      80.335097  19.664903

# %%
pd.crosstab(df["SeniorCitizen"], df["Churn"], normalize="index") * 100
# Out:
# Churn                 No        Yes
# SeniorCitizen
# 0              76.393832  23.606168
# 1              58.318739  41.681261
